# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings 
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("Smartphone_Usage_And_Addiction_Analysis_7500_Rows.csv")

# %%
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
df.tail()
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 7495       TXN07496  U07496   26   Other                     9.85
# 7496       TXN07497  U07497   35    Male                     5.67
# 7497       TXN07498  U07498   22  Female                     9.99
# 7498       TXN07499  U07499   23    Male                     8.74
# 7499       TXN07500  U07500   27  Female                    10.04
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 7495                1.75          3.13              3.49         5.81
# 7496                2.33          2.76              5.90         8.47
# 7497                3.61          1.09              1.16         8.17
# 7498                1.59          0.07              4.64         6.19
# 7499                5.40          0.73              5.45         5.58
#
#       notifications_per_day  app_opens_per_day  weekend_screen_time  \
# 7495                    249                122                11.99
# ...

# %%
df.sample(5)
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 7239       TXN07240  U07240   31    Male                     4.29
# 4975       TXN04976  U04976   28  Female                     9.28
# 4941       TXN04942  U04942   28    Male                     7.69
# 994        TXN00995  U00995   30  Female                    10.07
# 6729       TXN06730  U06730   20   Other                     7.98
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 7239                5.45          3.83              3.33         5.55
# 4975                1.94          2.03              2.66         6.52
# 4941                2.33          1.39              3.95         8.54
# 994                 5.19          2.44              1.36         8.81
# 6729                5.69          1.44              3.70         7.48
#
#       notifications_per_day  app_opens_per_day  weekend_screen_time  \
# 7239                     90                 97                 6.47
# ...

# %%
df.shape
# Out:
# (7500, 16)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# transaction_id               0
# user_id                      0
# age                          0
# gender                       0
# daily_screen_time_hours      0
# social_media_hours           0
# gaming_hours                 0
# work_study_hours             0
# sleep_hours                  0
# notifications_per_day        0
# app_opens_per_day            0
# weekend_screen_time          0
# stress_level                 0
# academic_work_impact         0
# addiction_level            819
# addicted_label               0
# dtype: int64

# %%
df.describe()
# Out:
#                age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# count  7500.000000              7500.000000         7500.000000   7500.000000
# mean     26.568800                 7.499912            3.273484      2.014183
# std       5.197108                 2.609188            1.585342      1.146039
# min      18.000000                 3.000000            0.500000      0.000000
# 25%      22.000000                 5.220000            1.910000      1.020000
# 50%      27.000000                 7.525000            3.270000      2.040000
# 75%      31.000000                 9.810000            4.630000      2.990000
# max      35.000000                12.000000            6.000000      4.000000
#
#        work_study_hours  sleep_hours  notifications_per_day  \
# count       7500.000000  7500.000000            7500.000000
# mean           3.242420     6.737561             134.257333
# std            1.600765     1.283605              66.586883
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           7500 non-null   object
#  1   user_id                  7500 non-null   object
#  2   age                      7500 non-null   int64
#  3   gender                   7500 non-null   object
#  4   daily_screen_time_hours  7500 non-null   float64
#  5   social_media_hours       7500 non-null   float64
#  6   gaming_hours             7500 non-null   float64
#  7   work_study_hours         7500 non-null   float64
#  8   sleep_hours              7500 non-null   float64
#  9   notifications_per_day    7500 non-null   int64
#  10  app_opens_per_day        7500 non-null   int64
#  11  weekend_screen_time      7500 non-null   float64
#  12  stress_level             7500 non-null   object
#  13  academic_work_impact     7500 non-null   object
# ...

# %%
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
sns.countplot(x = df['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = df['academic_work_impact'],palette='rainbow')
# Out:
# <Axes: xlabel='academic_work_impact', ylabel='count'>

# %%
sns.countplot(x = df['stress_level'])
# Out:
# <Axes: xlabel='stress_level', ylabel='count'>

# %%
sns.countplot(x = df['addiction_level'])
# Out:
# <Axes: xlabel='addiction_level', ylabel='count'>

# %%
df.corr(numeric_only=True)
# Out:
#                               age  daily_screen_time_hours  \
# age                      1.000000                 0.012767
# daily_screen_time_hours  0.012767                 1.000000
# social_media_hours       0.000342                 0.010321
# gaming_hours            -0.026107                 0.001140
# work_study_hours        -0.017147                 0.003108
# sleep_hours             -0.007462                 0.019343
# notifications_per_day    0.000387                 0.000811
# app_opens_per_day       -0.002276                 0.024448
# weekend_screen_time      0.015286                 0.964295
# addicted_label           0.004220                 0.577112
#
#                          social_media_hours  gaming_hours  work_study_hours  \
# age                                0.000342     -0.026107         -0.017147
# daily_screen_time_hours            0.010321      0.001140          0.003108
# social_media_hours                 1.000000     -0.000902         -0.002580
# ...

# %%
corr_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(9, 9))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, 
            mask=mask, 
            annot=True,      
            fmt=".2f",       
            cmap='coolwarm', 
            linewidths=0.5)

plt.title('Feature Correlation Matrix', fontsize=16)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
X = df[['age','gender','daily_screen_time_hours','social_media_hours','gaming_hours','sleep_hours','app_opens_per_day','weekend_screen_time','stress_level','academic_work_impact','addiction_level']]

# %%
X.head()
# Out:
#    age gender  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0   21   Male                     3.23                2.01          0.89
# 1   24  Other                     5.09                3.81          2.24
# 2   31  Other                     6.06                1.36          3.83
# 3   32  Other                     7.83                5.85          1.51
# 4   25   Male                     9.96                5.92          3.42
#
#    sleep_hours  app_opens_per_day  weekend_screen_time stress_level  \
# 0         7.55                154                 3.95       Medium
# 1         7.66                 71                 6.71       Medium
# 2         4.92                106                 8.68         High
# 3         8.23                107                 9.77         High
# 4         6.21                177                12.55          Low
#
#   academic_work_impact addiction_level
# 0                  Yes             NaN
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,df['addicted_label'],test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (6000, 11)

# %%
X_train.head()
# Out:
#       age  gender  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 4664   28    Male                     4.90                1.92          3.41
# 4411   22  Female                     4.70                4.14          0.33
# 7448   29    Male                     8.13                1.83          3.11
# 1919   27  Female                     5.48                2.72          1.10
# 1298   29    Male                     7.90                1.31          2.64
#
#       sleep_hours  app_opens_per_day  weekend_screen_time stress_level  \
# 4664         5.90                122                 6.70         High
# 4411         5.51                 90                 6.76         High
# 7448         6.29                138                 8.79         High
# 1919         5.24                104                 6.14       Medium
# 1298         6.98                111                 9.26         High
#
#      academic_work_impact addiction_level
# ...

# %%
X_test.head()
# Out:
#       age  gender  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 970    30   Other                     7.45                3.05          3.30
# 6279   25  Female                     8.10                5.33          0.04
# 1859   32    Male                     7.21                1.70          3.76
# 6803   35  Female                     8.90                1.44          2.98
# 6305   21  Female                     7.06                1.40          2.92
#
#       sleep_hours  app_opens_per_day  weekend_screen_time stress_level  \
# 970          8.66                117                 8.67         High
# 6279         7.11                177                10.05          Low
# 1859         7.77                 23                10.10       Medium
# 6803         7.33                107                 9.81       Medium
# 6305         8.53                 97                 9.63       Medium
#
#      academic_work_impact addiction_level
# ...

# %%
X_test.shape
# Out:
# (1500, 11)

# %%
y_train.shape
# Out:
# (6000,)

# %%
y_test.shape
# Out:
# (1500,)

# %%
df.isna().sum()
# Out:
# transaction_id               0
# user_id                      0
# age                          0
# gender                       0
# daily_screen_time_hours      0
# social_media_hours           0
# gaming_hours                 0
# work_study_hours             0
# sleep_hours                  0
# notifications_per_day        0
# app_opens_per_day            0
# weekend_screen_time          0
# stress_level                 0
# academic_work_impact         0
# addiction_level            819
# addicted_label               0
# dtype: int64

# %%
tr2 = ColumnTransformer(transformers=[
    ('sex', OneHotEncoder(handle_unknown='ignore', sparse_output=False), ['gender']),
    ('ord', OrdinalEncoder(categories=[
        ['Low','Medium','High'],
        ['No','Yes'],
        ['Mid','Mild','Severe']
    ]), ['stress_level','academic_work_impact','addiction_level'])
], remainder='passthrough')

# %%
tr2
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('sex',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['gender']),
#                                 ('ord',
#                                  OrdinalEncoder(categories=[['Low', 'Medium',
#                                                              'High'],
#                                                             ['No', 'Yes'],
#                                                             ['Mid', 'Mild',
#                                                              'Severe']]),
#                                  ['stress_level', 'academic_work_impact',
#                                   'addiction_level'])])

# %%
ord_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder(
        categories=[
            ['Low','Medium','High'],
            ['No','Yes'],
            ['Mid','Mild','Severe']
        ],
        handle_unknown='use_encoded_value',
        unknown_value=-1
    ))
])

preprocessor = ColumnTransformer(transformers=[

    ('sex', OneHotEncoder(handle_unknown='ignore', sparse_output=False), ['gender']),

    ('ord', ord_pipe, ['stress_level','academic_work_impact','addiction_level'])

], remainder='passthrough')

# %%
pipe1 = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression())
])

# %%
pipe1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('sex',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['gender']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(categories=[['Low',
#                                                                                                'Medium',
# ...

# %%
y_pred = pipe1.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8766666666666667

# %%
pipe2 = Pipeline(steps=[
    ('pre',preprocessor), 
    ('model',DecisionTreeClassifier())
])

# %%
pipe2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('sex',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['gender']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(categories=[['Low',
#                                                                                                'Medium',
# ...

# %%
y2_pred = pipe2.predict(X_test)

# %%
accuracy_score(y_test,y2_pred)
# Out:
# 0.9993333333333333

# %%
scores = cross_val_score(pipe2, X_train, y_train, cv=5)

print(scores)
print("Mean Accuracy:", scores.mean())
# Out:
# [0.99833333 1.         1.         0.99916667 1.        ]
# Mean Accuracy: 0.9994999999999999

# %%
scores = cross_val_score(pipe1, X_train, y_train, cv=5)

print(scores)
print("Mean Accuracy:", scores.mean())
# Out:
# [0.875      0.88       0.8775     0.88833333 0.87166667]
# Mean Accuracy: 0.8785000000000001
